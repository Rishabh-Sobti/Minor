# %%
import pandas as pd
import os
import requests
from PIL import Image
from io import BytesIO

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Documents\\GitHub\\Minor'

# %%
df1 = pd.read_csv('combined/6.csv')

# %%
df1.head()
# Out:
#      Bahala (20-N))  06  085  00413  062336  0.0845755953183  \
# 0  Naya Gaon (21-N)   6   85    413   62337         0.107172
# 1      Gadhi (25-N)   6   85    413   62338         0.076065
# 2       Bawa (22-N)   6   85    413   62339         0.130149
# 3     Karoli (23-N)   6   85    413   62340         0.107789
# 4     Bisoha (24-N)   6   85    413   62341         0.103553
#
#    0.000386845693139  76.29207947793293  28.41427717747939  78.8   1.1  \
# 0           0.000452          76.310324          28.417301  84.7  29.7
# 1           0.000232          76.328743          28.414865  75.4  47.4
# 2           0.001027          76.316248          28.392183  92.0  66.6
# 3           0.000729          76.340858          28.378671  88.7  35.3
# 4           0.000597          76.348535          28.402105  88.6  13.8
#
#    23.366666666666664  73.4  32.2
# 0           21.133333  79.6  36.4
# 1           25.266667  78.4  40.3
# 2           24.800000  78.1  27.2
# ...

# %%
df1.columns =['Name ' , 'State' , 'District' , 'tehsil' , 'village' , 'shape_length' , 'shape_area' , 'longtitude' , 'latitude' , 'electricity' , 'treated_water' , 'electronics' , 'phone' , 'transport']        
df1.to_csv('combined/haryana.csv' , index= False, header = 'none')

# %%
df=pd.read_csv('combined/haryana.csv' )

# %%
df.head()
# Out:
#               Name   State  District  tehsil  village  shape_length  \
# 0  Naya Gaon (21-N)      6        85     413    62337      0.107172
# 1      Gadhi (25-N)      6        85     413    62338      0.076065
# 2       Bawa (22-N)      6        85     413    62339      0.130149
# 3     Karoli (23-N)      6        85     413    62340      0.107789
# 4     Bisoha (24-N)      6        85     413    62341      0.103553
#
#    shape_area  longtitude   latitude  electricity  treated_water  electronics  \
# 0    0.000452   76.310324  28.417301         84.7           29.7    21.133333
# 1    0.000232   76.328743  28.414865         75.4           47.4    25.266667
# 2    0.001027   76.316248  28.392183         92.0           66.6    24.800000
# 3    0.000729   76.340858  28.378671         88.7           35.3    30.700000
# 4    0.000597   76.348535  28.402105         88.6           13.8    32.600000
#
#    phone  transport
# 0   79.6       36.4
# 1   78.4       40.3
# 2   78.1       27.2
# ...

# %%
url = 'https://maps.googleapis.com/maps/api/staticmap?'
df.latitude= df.latitude.astype('object')
df.longtitude=df.longtitude.astype('object')
folder = 'google_images_haryana'
if not os.path.exists(folder):
    os.makedirs(folder)
os.getcwd()
os.chdir("google_images_haryana")   
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Documents\\GitHub\\Minor\\google_images_haryana'

# %%
c1 =[]
c2 =[]
c=[]
for lat in df.latitude:
    c1= str(lat)
    for long in df.longtitude:
        c2 = str(long)
        c = c1 + ',' + c2
        try : 
            
       
            r = requests.get(url+"center="+c+'&zoom=15&size=640x640&maptype=satellite&key=AIzaSyDnDm2kDvLJvjySSHOpBNFEt8Jw4UJU_8U')
            im = Image.open(BytesIO(r.content)) 
        
            image_file_format = '.BMP'
            im.save( c + image_file_format)

        except requests.exceptions.RequestException as e:
                print(e)
                sys.exit(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-123-7755dfce1ad8> in <module>()
#      10
#      11
# ---> 12             r = requests.get(url+"center="+c+'&zoom=15&size=640x640&maptype=satellite&key=AIzaSyDnDm2kDvLJvjySSHOpBNFEt8Jw4UJU_8U')
# ...
